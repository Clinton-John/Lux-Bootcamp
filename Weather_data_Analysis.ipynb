# %%
import pandas as pd
import numpy as np

# %%
weather_df = pd.read_csv('/content/1. Weather Data.csv')

# %%
weather_df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
#to find the number of rows and the number of columns
weather_df.shape
# Out:
# (8784, 8)

# %% [markdown]
# Find all records where the weather was exactly clear.
#
# Find the number of times the wind speed was exactly 4 km/hr.
#
# Check if there are any NULL values present in the dataset.
#
# Rename the column "Weather" to "Weather_Condition."
#
# What is the mean visibility of the dataset?
#
# Find the number of records where the wind speed is greater than 24 km/hr and visibility is equal to 25 km.
#
# What is the mean value of each column for each weather condition?
#
# Find all instances where the weather is clear and the relative humidity is greater than 50, or visibility is above 40.
#
# Find the number of weather conditions that include snow.
#
# Part 2: Move this CSV into a database of your choice and use SQL to answer

# %%
#to find the records where the weather was clear
clear_weather = weather_df[weather_df['Weather'] == 'Clear']

# %%
#to find the number of records having a clear weather
clear_weather.shape
# Out:
# (1326, 8)

# %%
#2. Find the number of times the wind speed was exactly 4 km/hr.
wind_speed_4kmh = weather_df[weather_df['Wind Speed_km/h'] == 4 ]
wind_speed_4kmh.shape
# Out:
# (474, 8)

# %%
#3. Check if there are any NULL values present in the dataset.
weather_df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
#4, Rename the column "Weather" to "Weather_Condition."
weather_df2 = weather_df.rename(columns = {'Weather' : 'Weather_Condition'})
weather_df2.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather_Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
#5. What is the mean visibility of the dataset?
mean_visibility = weather_df.Visibility_km.mean()
mean_visibility
# Out:
# 27.664446721311478

# %%
#6. Find the number of records where the wind speed is greater than 24 km/hr and visibility is equal to 25 km.

query1 = weather_df2[(weather_df['Wind Speed_km/h'] > 24) & (weather_df2['Visibility_km'] == 25)]
query1.shape
# Out:
# (308, 8)

# %%
#7. What is the mean value of each column for each weather condition?
mean_values = weather_df2.describe()
print(mean_values)
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
# What is the mean value of each column for each weather condition?
# weather_df3 = weather_df2.drop(['Date/Time'], axis = 1) # python cant calculate the mean of a date format
# mean_values2 = weather_df3.groupby('Weather_Condition').mean()
# print(mean_values2)

# %%
#8. Find all instances where the weather is clear and the relative humidity is greater than 50, or visibility is above 40.

query2 = weather_df2[(weather_df2['Weather_Condition'] == 'Clear') & ((weather_df2['Rel Hum_%'] > 50) | (weather_df2['Visibility_km'] > 40 ))]
query2.shape
# Out:
# (1220, 8)

# %%
#The answer for the above question.
#There are a total of 1220 instances
query2.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
# 115  1/5/2012 19:00    -9.2             -15.4         61                7
# 116  1/5/2012 20:00    -9.8             -15.7         62                9
# 117  1/5/2012 21:00    -9.0             -14.8         63               13
# 241  1/11/2012 1:00   -10.7             -17.8         56               17
#
#      Visibility_km  Press_kPa Weather_Condition
# 114           25.0     100.71             Clear
# 115           25.0     100.80             Clear
# 116           25.0     100.83             Clear
# 117           25.0     100.83             Clear
# 241           25.0     101.49             Clear

# %%
#9.Find the number of weather conditions that include snow.
weather_df2.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather_Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
# 9.Find the number of weather conditions that include snow
weather_with_snow = weather_df2[weather_df2['Weather_Condition'].str.contains('Snow')]
weather_with_snow.shape
# Out:
# (583, 8)

# %%
#There are a total of 583 weather conditions that include the word snow
weather_with_snow.head()
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41  1/2/2012 17:00    -2.1              -9.5         57               22
# 44  1/2/2012 20:00    -5.6             -13.4         54               24
# 45  1/2/2012 21:00    -5.8             -12.8         58               26
# 47  1/2/2012 23:00    -7.4             -14.1         59               17
# 48   1/3/2012 0:00    -9.0             -16.0         57               28
#
#     Visibility_km  Press_kPa Weather_Condition
# 41           25.0      99.66      Snow Showers
# 44           25.0     100.07      Snow Showers
# 45           25.0     100.15      Snow Showers
# 47           19.3     100.27      Snow Showers
# 48           25.0     100.35      Snow Showers
